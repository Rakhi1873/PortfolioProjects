# %%
# importing libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\Titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 31.1+ KB

# %%
df['Ticket'].drop_duplicates()
# Out:
# 0                  330911
# 1                  363272
# 2                  240276
# 3                  315154
# 4                 3101298
# 5                    7538
# 6                  330972
# 7                  248738
# 8                    2657
# 9               A/4 48871
# 10                 349220
# 11                    694
# 12                  21228
# 13                  24065
# 14            W.E.P. 5734
# 15          SC/PARIS 2167
# 16                 233734
# 17                   2692
# 18       STON/O2. 3101270
# 19                   2696
# 20               PC 17603
# 21                C 17368
# 22               PC 17598
# 23               PC 17597
# 24               PC 17608
# 25              A/5. 3337
# 26                 113509
# 27                   2698
# 28                 113054
# 29                   2662
# 30             SC/AH 3085
# 31             C.A. 31029
# 32              C.A. 2315
# 33             W./C. 6607
# 34                  13236
# ...

# %%
pd.set_option('display.max_rows', None)

df.sort_values(by='Ticket', inplace=False, ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 335         1227         0       1
# 158         1050         0       1
# 236         1128         0       1
# 191         1083         0       1
# 266         1158         0       1
# 372         1264         0       1
# 240         1132         1       1
# 368         1260         1       1
# 402         1294         1       1
# 305         1197         1       1
# 215         1107         0       1
# 355         1247         0       1
# 28           920         0       1
# 403         1295         0       1
# 74           966         1       1
# 218         1110         1       1
# 75           967         0       1
# 407         1299         0       1
# 26           918         1       1
# 182         1074         1       1
# 41           933         0       1
# 131         1023         0       1
# 141         1033         1       1
# 306         1198         0       1
# 323         1215         0       1
# ...

# %%
sns.countplot(x=df['Survived'], hue=df['Sex'])
plt.show()
# 0 MEANS NOT SURVIVED AND 1 MEANS SURVIVED

# %%
# checking the age groups of the people

sns.histplot(data = df['Age'], kde=True, bins=15)
plt.show()

# %%
plt.scatter(x=df['Survived'], y=df['Age'])
plt.show()

# %%
df.corr(method='pearson')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2724\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age            -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp           0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# ...

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2724\1460020885.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')

# %% [markdown]
# # The data at age x survived is showing a infinite value due to the lack of entries.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df1 = df

# %%
df1 = df1.fillna({'Age':30})

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df1.corr()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2724\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.030935  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615  0.000662  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.443234  0.001087  0.018721
# Age            -0.030935  0.000662 -0.443234  1.000000 -0.078870 -0.044980
# SibSp           0.003818  0.099943  0.001087 -0.078870  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.044980  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.330721  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Survived     0.191514
# ...

# %%
sns.heatmap(df1.corr(), annot=True)
plt.title('Correlations')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2724\1187628262.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(), annot=True)

# %%
df.corr().unstack()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2724\4102424629.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().unstack()
# PassengerId  PassengerId    1.000000
#              Survived      -0.023245
#              Pclass        -0.026751
#              Age           -0.034102
#              SibSp          0.003818
#              Parch          0.043080
#              Fare           0.008211
# Survived     PassengerId   -0.023245
#              Survived       1.000000
#              Pclass        -0.108615
#              Age           -0.000013
#              SibSp          0.099943
#              Parch          0.159120
#              Fare           0.191514
# Pclass       PassengerId   -0.026751
#              Survived      -0.108615
#              Pclass         1.000000
# ...

# %%
df4= df.corr().unstack()
df4.sort_values()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2724\2967162097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df4= df.corr().unstack()
# Fare         Pclass        -0.577147
# Pclass       Fare          -0.577147
# Age          Pclass        -0.492143
# Pclass       Age           -0.492143
# Survived     Pclass        -0.108615
# Pclass       Survived      -0.108615
# SibSp        Age           -0.091587
# Age          SibSp         -0.091587
# Parch        Age           -0.061249
# Age          Parch         -0.061249
#              PassengerId   -0.034102
# PassengerId  Age           -0.034102
#              Pclass        -0.026751
# Pclass       PassengerId   -0.026751
# PassengerId  Survived      -0.023245
# Survived     PassengerId   -0.023245
#              Age           -0.000013
# ...
